# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as mp
import warnings
warnings.filterwarnings('ignore')

# %%
sa=pd.read_csv(r"C:\Users\shruti\Downloads\Iris.csv")

# %%
sa
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
sa.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
sb.relplot(data=sa,x='Id',y='SepalWidthCm',col='PetalLengthCm',hue='SepalLengthCm',style='PetalWidthCm')

# %%
sa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
sa.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
mp.figure(figsize=(9,3))
mp.scatter(sa['Id'],sa['PetalWidthCm'])
mp.xlabel("Id")
mp.ylabel("PetalWidthCm")
# Out:
# Text(0, 0.5, 'PetalWidthCm')

# %%
mp.figure(figsize=(9,3))
mp.plot(sa['Id'],sa['PetalWidthCm'])
mp.xlabel("Id")
mp.ylabel("PetalWidthCm")
# Out:
# Text(0, 0.5, 'PetalWidthCm')

# %%
def bar_plot(variable):
    var=sa[variable]
    varValue=var.value_counts()
    mp.figure(figsize=(9,3))
    mp.bar(varValue.index,varValue)
    mp.xticks(varValue.index,varValue.index.values)
    mp.ylabel("Frequency")
    mp.title(variable)
    mp.show()
    print("{}:\n{}".format(variable,varValue))

# %%
columns_plot=['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm','Species']
for i in columns_plot:
    bar_plot(i)
# Out:
# Id:
# 1      1
# 95     1
# 97     1
# 98     1
# 99     1
#       ..
# 51     1
# 52     1
# 53     1
# 54     1
# 150    1
# Name: Id, Length: 150, dtype: int64
# SepalLengthCm:
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: SepalLengthCm, dtype: int64
# SepalWidthCm:
# 3.0    26
# 2.8    14
# 3.2    13
# 3.1    12
# 3.4    12
# 2.9    10
# 2.7     9
# 2.5     8
# 3.5     6
# 3.3     6
# 3.8     6
# 2.6     5
# 2.3     4
# 3.7     3
# 2.4     3
# 2.2     3
# 3.6     3
# 3.9     2
# 4.4     1
# 4.0     1
# 4.1     1
# 4.2     1
# 2.0     1
# Name: SepalWidthCm, dtype: int64
# PetalLengthCm:
# 1.5    14
# ...

# %%
mp.hist(sa['Id'])
# Out:
# (array([15., 15., 15., 15., 15., 15., 15., 15., 15., 15.]),
#  array([  1. ,  15.9,  30.8,  45.7,  60.6,  75.5,  90.4, 105.3, 120.2,
#         135.1, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
mp.hist(sa['SepalLengthCm'])
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
mp.hist(sa['SepalWidthCm'])
# Out:
# (array([ 4.,  7., 22., 24., 38., 31.,  9., 11.,  2.,  2.]),
#  array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ]),
#  <BarContainer object of 10 artists>)

# %%
mp.hist(sa['PetalLengthCm'])
# Out:
# (array([37., 13.,  0.,  3.,  8., 26., 29., 18., 11.,  5.]),
#  array([1.  , 1.59, 2.18, 2.77, 3.36, 3.95, 4.54, 5.13, 5.72, 6.31, 6.9 ]),
#  <BarContainer object of 10 artists>)

# %%
mp.hist(sa['PetalWidthCm'])
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <BarContainer object of 10 artists>)

# %%
mp.hist(sa['Species'])
# Out:
# (array([50.,  0.,  0.,  0.,  0., 50.,  0.,  0.,  0., 50.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
sb.lmplot(x='Id',y='PetalWidthCm',data=sa)

# %%
sb.violinplot(sa)
# Out:
# <Axes: >

# %%
sb.violinplot(sa['Id'])
# Out:
# <Axes: >

# %%
sb.violinplot(sa['PetalWidthCm'])
# Out:
# <Axes: >

# %%
sb.violinplot(sa['PetalLengthCm'])
# Out:
# <Axes: >

# %%
sb.violinplot(sa['SepalWidthCm'])
# Out:
# <Axes: >

# %%
sb.violinplot(sa['SepalLengthCm'])
# Out:
# <Axes: >

# %%
sb.pairplot(sa)

# %%
mp.subplot(3,2,1)
mp.title('Species')
mp.hist(sa['Species'])
mp.subplot(3,2,2)
mp.title('PetalWidthCm')
mp.hist(sa['PetalWidthCm'])
mp.subplot(3,2,5)
mp.title('SepalWidthCm')
mp.hist(sa['SepalWidthCm'])
mp.subplot(3,2,6)
mp.title('Id')
mp.hist(sa['Id'])
mp.show()

# %%
sa[['Id','PetalWidthCm']].groupby(['Id'],as_index=False).mean().sort_values(by='PetalWidthCm',ascending=False)
# Out:
#       Id  PetalWidthCm
# 100  101           2.5
# 109  110           2.5
# 144  145           2.5
# 114  115           2.4
# 140  141           2.4
# ..   ...           ...
# 13    14           0.1
# 37    38           0.1
# 32    33           0.1
# 34    35           0.1
# 9     10           0.1
#
# [150 rows x 2 columns]

# %%
sa[['SepalWidthCm','SepalLengthCm']].groupby(['SepalWidthCm'],as_index=False).mean().sort_values(by='SepalLengthCm',ascending=False)
# Out:
#     SepalWidthCm  SepalLengthCm
# 7            2.8       6.335714
# 5            2.6       6.160000
# 17           3.8       6.100000
# 1            2.2       6.066667
# 8            2.9       6.060000
# 12           3.3       6.016667
# 9            3.0       6.015385
# 10           3.1       5.941667
# 11           3.2       5.884615
# 6            2.7       5.855556
# 19           4.0       5.800000
# 4            2.5       5.762500
# 22           4.4       5.700000
# 15           3.6       5.600000
# 21           4.2       5.500000
# 18           3.9       5.400000
# 2            2.3       5.325000
# 13           3.4       5.316667
# 3            2.4       5.300000
# 16           3.7       5.266667
# 20           4.1       5.200000
# 14           3.5       5.150000
# 0            2.0       5.000000

# %%
sb.boxplot(sa['Id'])
# Out:
# <Axes: >

# %%
sb.boxplot(sa['SepalWidthCm'])
# Out:
# <Axes: >

# %%
sb.boxplot(sa['SepalLengthCm'])
# Out:
# <Axes: >

# %%
sb.boxplot(sa['PetalWidthCm'])
# Out:
# <Axes: >

# %%
sb.boxplot(sa['PetalLengthCm'])
# Out:
# <Axes: >

# %%
sa['Id']=sa['Id'].fillna(sa['Id'].median())

# %%
sa['PetalLengthCm']=sa['PetalLengthCm'].fillna(sa['PetalLengthCm'].median())

# %%
sa.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
sa['PetalLengthCm'].mode()
# Out:
# 0    1.5
# Name: PetalLengthCm, dtype: float64

# %%
sa['PetalLengthCm']=sa['PetalLengthCm'].fillna(sa['PetalLengthCm'].mode()[0])

# %%
sa.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
sa.drop(labels=['Species'],axis=1,inplace=True)

# %%
sa.head(3)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0   1            5.1           3.5            1.4           0.2
# 1   2            4.9           3.0            1.4           0.2
# 2   3            4.7           3.2            1.3           0.2

# %%
sa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
sa.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0   1            5.1           3.5            1.4           0.2
# 1   2            4.9           3.0            1.4           0.2
# 2   3            4.7           3.2            1.3           0.2
# 3   4            4.6           3.1            1.5           0.2
# 4   5            5.0           3.6            1.4           0.2

# %%
sb.heatmap(sa.corr(),annot=True,fmt='.2f')
# Out:
# <Axes: >

# %%
Id=np.array([1,2,3,4,5])
SepalLengthCm=np.array([5.1,4.9,4.7,4.6,5.0])
mp.pie(SepalLengthCm,labels=Id)
# Out:
# ([<matplotlib.patches.Wedge at 0x1c55fa8b210>,
# ...
#  [Text(0.869431917387439, 0.6738606243341435, '1'),
#   Text(-0.4094288470404943, 1.0209642595169979, '2'),
#   Text(-1.09852946383526, -0.056859626149108035, '3'),
#   Text(-0.3426223903931884, -1.0452798178484353, '4'),
#   Text(0.8780711131409357, -0.6625640499358821, '5')])
